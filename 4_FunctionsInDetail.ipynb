# %% [markdown]
# # Functions

# %%
#Function basic demo

def subtract(a,b):
    """  This function adds two numbers   """
    print("Calculating difference between of {} and {}".format(a,b))
    return a-b


num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

print("Result is ",subtract(b = num2, a = num1))    # Order specified explicitly
print("Result is ",subtract(num1, num2))    # Default order maintained
print("Result is ",subtract(num2, num1))    # Order reversed
# Out:
# Calculating difference between of 30 and 20
# Result is  10
# Calculating difference between of 30 and 20
# Result is  10
# Calculating difference between of 20 and 30
# Result is  -10

# %%
# None Type demo
def testFunction():
  # This function is doing nothing.
  pass
  print("This will be printed")
  return
  print("This will not be printed due to above return statement")



ret = testFunction()
print("Printing ret value and type :", ret, "      ",type(ret))
# Out:
# This will be printed
# Printing ret value and type : None        <class 'NoneType'>

# %%
# return statement can return multiple values.

def divideEachBy2(a, b):
  return a/2, b/2

print(divideEachBy2(10, 5))
print(type(divideEachBy2(10, 5)))
print("**************************")
print(divideEachBy2(10, 5)[0])
print(divideEachBy2(10, 5)[1])
# Out:
# (5.0, 2.5)
# <class 'tuple'>
# **************************
# 5.0
# 2.5

# %%
# Variable number of args to a function
def printAllNumbers(**abc):    # Arg is like dictionary, if we pass **abc
  print("Type of input variable  ",type(abc))
  for item in abc.items():
    print(item[0], item[1])

  print("***********")
  for key, value in abc.items():
    print(key, value, type(value))

  print("***********")
  for key in abc:
    print(key, abc[key], type(abc[key]))


printAllNumbers(abc=20, b=30, d=100, name="Binu Andrews")
# Out:
# Type of input variable   <class 'dict'>
# abc 20
# b 30
# d 100
# name Binu Andrews
# ***********
# abc 20 <class 'int'>
# b 30 <class 'int'>
# d 100 <class 'int'>
# name Binu Andrews <class 'str'>
# ***********
# abc 20 <class 'int'>
# b 30 <class 'int'>
# d 100 <class 'int'>
# name Binu Andrews <class 'str'>

# %%
# Call by value
def myFunctionCallByValue(inputVar):
  print("Param before update inside function",inputVar)
  inputVar = inputVar * 2
  print("Param after update inside function",inputVar)


inputVar = 10
print("Param value from main before function call",inputVar)
myFunctionCallByValue(inputVar)
print("Param value from main after function call",inputVar)
# Out:
# Param value from main before function call 10
# Param before update inside function 10
# Param after update inside function 20
# Param value from main after function call 10

# %%
# Call by refernce
def myFunctionCallByValue(inputVar):
  print("Param before update inside function",inputVar)
  for item in inputVar:
    inputVar[item] *= 2
  print("Param after update inside function",inputVar)


myDict = {"abc": 10, "def": 20}
print("Param value from main before function call",myDict)
myFunctionCallByValue(myDict)
print("Param value from main after function call",myDict  )
# Out:
# Param value from main before function call {'abc': 10, 'def': 20}
# Param before update inside function {'abc': 10, 'def': 20}
# Param after update inside function {'abc': 20, 'def': 40}
# Param value from main after function call {'abc': 20, 'def': 40}

# %%
#Default values for method

def functionPrimitive(inputVar=20):
  print(inputVar)

functionPrimitive(30)
functionPrimitive()
# Out:
# 30
# 20

# %%
# Function Passing List
def functionList(listVar=[10, 9]):
  listVar[0]=25
  print(listVar)


myList = [1, 2, 3]
# functionList(myList)
functionList()
# print(myList)
# Out:
# [25, 9]
