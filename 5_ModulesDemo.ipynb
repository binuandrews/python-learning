# %% [markdown]
# # Demo on Modules

# %%
import importlib
import GlobalCalcModules as gc
importlib.reload(gc)
print(gc.addTwoNumbers(3, 3))
# Out:
# 6

# %%
# Passing a list to the method in to the module.
myList = [1, 2, 7]
print(gc.addAllNumbers(myList))
# Out:
# Print before return
# 10

# %%
#Print All the numbers

gc.printAllNumbers(1, 2, 3)
# Out:
# 1
# 2
# 3

# %%
# Check any non int in list or not.
from GlobalCalcModules import checkifNumeric
checkifNumeric(1.0, 1, 2, 3)
# Out:
# 1.0
# 1
# 2
# 3
# True

# %%
# Sorting Demo using modules

myList = [9,30,56,-10, -7, 21.1, 10, 2,29]

print(gc.sortList(myList))
# Out:
# Print before sort [9, 30, 56, -10, -7, 21.1, 10, 2, 29]
# [-10, -7, 2, 9, 10, 21.1, 29, 30, 56]
